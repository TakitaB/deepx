# %%
import os
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
pics = os.listdir("../raw_data/Sample_Images")
len(pics)
# Out:
# 138

# %%
import matplotlib.image as mpimg

image = mpimg.imread(f'../raw_data/Sample_Images/{pics[0]}')
plt.imshow(image)

# %%
resize_image = tf.image.resize(image, [128, 128]) #resize
resized = tf.image.rgb_to_grayscale(resize_image) #grayscale
#resized

# %%
tf.keras.utils.save_img('../raw_data/Sample_Images/', resized)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.8.12/envs/deepx/lib/python3.8/site-packages/PIL/Image.py:2192, in Image.save(self, fp, format, **params)
#    2191 try:
# -> 2192     format = EXTENSION[ext]
#    2193 except KeyError as e:
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 tf.keras.utils.save_img('../raw_data/Sample_Images/', resized)
#
# File ~/.pyenv/versions/3.8.12/envs/deepx/lib/python3.8/site-packages/keras/preprocessing/image.py:270, in save_img(path, x, data_format, file_format, scale, **kwargs)
#     268 if data_format is None:
#     269   data_format = backend.image_data_format()
# --> 270 image.save_img(path,
#     271                x,
# ...

# %%
for pic in pics:
    img.imread(f'../raw_data/Sample_Images/{pic}') #reads image
    
    tf.image.resize(image, [128, 128]) #resize
    tf.image.rgb_to_grayscale(resize_image) #grayscale
    #plt.savefig(f'..\raw_data\Sample_Images{pic}')#Store/Move to folder
    #../raw_data/Sample_Images/{pic}

# %%
import tensorflow as tf
resize_image = tf.image.resize(image, [128, 128])

rescaled = tf.image.rgb_to_grayscale(resize_image)

plt.imshow(rescaled, cmap='gray')
plt.show()
